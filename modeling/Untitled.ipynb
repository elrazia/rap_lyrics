# %%
import pandas as pd

# %%
df = pd.read_pickle('/Users/El-Razi/ds/metis/git/rap_lyrics/corpora/corpus_one.pkl')

# %%
frame = pd.DataFrame(df).T

# %%
frame.head(40)
# Out:
#                                                                                                artist  \
#                                                     [Big Russian Boss,                   The Inkre...
# "Clapping For The Wrong Reasons" Screenplay         [Childish Gambino,                   F.A.M.,  ...
# "Democracy: A Fable"                                                                    [David Bruce]
# "Find Out" (Real Nigga News)                        [Ill Camille,                   BJ The Chicago...
# "Grammy Family" Freestyle                                                                     [Jay Z]
# "Rap God" Freestyle                                               [Papoose, Mixtape "Hoodie Season" ]
# "The Wire" Episode Title and Epigraph Meanings                                             [The Wire]
# "This Is Water" (Kenyon College Commencement Ad...                             [David Foster Wallace]
# ...
